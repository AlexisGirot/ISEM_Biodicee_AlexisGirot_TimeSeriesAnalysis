# %%
# %%time
import numpy as np

import ISEM_Biodicee_AlexisGirot_TimeSeriesAnalysis as TSA
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# CPU times: user 5.15 s, sys: 1.48 s, total: 6.62 s
# Wall time: 5.54 s

# %%
# %%time
# folder = "/home/alexis/Documents/Travail/2023-2024/Stage Biodicee/Timeseries-analysis/Data/"

# with open(folder + "Simulated data/all_simu_mar_r1.csv") as f:
#     TS_sim = TSA.TS_list(data = f, method = "by_col", delimiter = ',', cols = {"id":["scen","iter","sr"], "time":"year", "Y":"TB"}, name = "Simulated time series", to_keep = ["expected_class", "expected_traj"])

# asd_thr = 0.15
# TS_sim.mc_classify(asd_thr = asd_thr)

# %%
# %%time
folder = "/home/alexis/Documents/Travail/2023-2024/Stage Biodicee/Timeseries-analysis/Data/"

with open(folder + "LPD2022_public/LPD2022_public.csv") as f:
    TS_LPD = TSA.TS_list(f, method = "by_row", delimiter = ",", rows = {"id":["ID",], "time":np.arange(1950, 2021)}, to_keep = ("Binomial"), name = "LPD time series")

asd_thr = 0.2
TS_LPD.mc_classify(asd_thr = asd_thr)
# Out:
# R[write to console]: Registered S3 method overwritten by 'MuMIn':
#   method     from
#   coef.geese kyotil
#
# R[write to console]: Registered S3 method overwritten by 'MuMIn':
#   method     from
#   coef.geese kyotil
#
# R[write to console]: Registered S3 method overwritten by 'MuMIn':
#   method     from
#   coef.geese kyotil
#
# R[write to console]: Registered S3 method overwritten by 'MuMIn':
#   method     from
#   coef.geese kyotil
#
# R[write to console]: Registered S3 method overwritten by 'MuMIn':
#   method     from
#   coef.geese kyotil
#
# R[write to console]: Registered S3 method overwritten by 'MuMIn':
#   method     from
#   coef.geese kyotil
#
# R[write to console]: Registered S3 method overwritten by 'MuMIn':
#   method     from
#   coef.geese kyotil
#
# R[write to console]: Registered S3 method overwritten by 'MuMIn':
#   method     from
#   coef.geese kyotil
# [1] "10/675"
# [1] "10/549"
# [1] "10/553"
# [1] "10/26"
# [1] "10/656"
# [1] "10/587"
# [1] "10/1619"
# ...
